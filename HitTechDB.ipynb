-- %% [markdown]
-- # [HitTechDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [HitTechDB]    Script Date: 2020-12-15 11:28:32 PM ******/
CREATE DATABASE [HitTechDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Hit-TechDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER2017\MSSQL\DATA\Hit-TechDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Hit-TechDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER2017\MSSQL\DATA\Hit-TechDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [HitTechDB] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [HitTechDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [HitTechDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [HitTechDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [HitTechDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [HitTechDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [HitTechDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [HitTechDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [HitTechDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [HitTechDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [HitTechDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [HitTechDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [HitTechDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [HitTechDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [HitTechDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [HitTechDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [HitTechDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [HitTechDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [HitTechDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [HitTechDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [HitTechDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [HitTechDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [HitTechDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [HitTechDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [HitTechDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [HitTechDB] SET  MULTI_USER 
GO
ALTER DATABASE [HitTechDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [HitTechDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [HitTechDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [HitTechDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [HitTechDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [HitTechDB] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[AuthorBooks]

-- %%
USE [HitTechDB]
GO

-- %%
/****** Object:  Table [dbo].[AuthorBooks]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AuthorBooks](
	[AuthorId] [int] NOT NULL,
	[ISBN] [int] NOT NULL,
	[YearPublished] [int] NOT NULL,
	[Edition] [int] NOT NULL,
 CONSTRAINT [PK_AuthorBooks] PRIMARY KEY CLUSTERED 
(
	[AuthorId] ASC,
	[ISBN] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Authors]

-- %%
/****** Object:  Table [dbo].[Authors]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Authors](
	[AuthorId] [int] NOT NULL,
	[FirstName] [nvarchar](50) NOT NULL,
	[LastName] [nvarchar](50) NOT NULL,
	[Email] [nvarchar](150) NOT NULL,
 CONSTRAINT [PK_Authors] PRIMARY KEY CLUSTERED 
(
	[AuthorId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Books]

-- %%
/****** Object:  Table [dbo].[Books]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Books](
	[ISBN] [int] NOT NULL,
	[Title] [nvarchar](150) NOT NULL,
	[QOH] [int] NOT NULL,
	[Price] [int] NOT NULL,
	[CategoryId] [int] NOT NULL,
	[PublisherId] [int] NOT NULL,
 CONSTRAINT [PK_Books] PRIMARY KEY CLUSTERED 
(
	[ISBN] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[CategoryId] [int] NOT NULL,
	[CategoryName] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Categories] PRIMARY KEY CLUSTERED 
(
	[CategoryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Customers]

-- %%
/****** Object:  Table [dbo].[Customers]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Customers](
	[CustomerId] [int] NOT NULL,
	[CustomerName] [nvarchar](50) NOT NULL,
	[PhoneNumber] [int] NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[FaxNumber] [int] NOT NULL,
	[StreetName] [nvarchar](50) NOT NULL,
	[City] [nvarchar](50) NOT NULL,
	[PosalCode] [nvarchar](50) NOT NULL,
	[CreditLimt] [int] NOT NULL,
 CONSTRAINT [PK_Customers] PRIMARY KEY CLUSTERED 
(
	[CustomerId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
/****** Object:  Table [dbo].[Employees]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employees](
	[EmployeeId] [int] NOT NULL,
	[FirstName] [nvarchar](50) NOT NULL,
	[LastName] [nvarchar](50) NOT NULL,
	[Phone] [int] NOT NULL,
	[Email] [nvarchar](150) NOT NULL,
	[JobId] [int] NOT NULL,
 CONSTRAINT [PK_Employees] PRIMARY KEY CLUSTERED 
(
	[EmployeeId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Job]

-- %%
/****** Object:  Table [dbo].[Job]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Job](
	[JobId] [int] NOT NULL,
	[JobTitle] [nvarchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Order]

-- %%
/****** Object:  Table [dbo].[Order]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Order](
	[OrderId] [int] NOT NULL,
	[OrderDate] [date] NOT NULL,
	[OrderType] [nvarchar](50) NOT NULL,
	[RequiredDate] [date] NOT NULL,
	[ShippingDate] [date] NOT NULL,
	[OrderStatus] [nvarchar](50) NOT NULL,
	[CustomerId] [int] NOT NULL,
	[EmployeeId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderDetail]

-- %%
/****** Object:  Table [dbo].[OrderDetail]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderDetail](
	[OrderId] [int] NOT NULL,
	[ISBN] [int] NOT NULL,
	[Quantity] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Publishers]

-- %%
/****** Object:  Table [dbo].[Publishers]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Publishers](
	[PublisherId] [int] NOT NULL,
	[PublisherName] [nvarchar](50) NOT NULL,
	[WebSite] [nchar](10) NOT NULL,
 CONSTRAINT [PK_Publishers] PRIMARY KEY CLUSTERED 
(
	[PublisherId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 2020-12-15 11:28:32 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserId] [int] NOT NULL,
	[Password] [nvarchar](100) NOT NULL,
	[UserStatus] [nvarchar](50) NOT NULL,
	[EmployeeId] [int] NOT NULL,
 CONSTRAINT [PK_Users] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AuthorBooks]

-- %%
INSERT [dbo].[AuthorBooks] ([AuthorId], [ISBN], [YearPublished], [Edition]) VALUES (201, 214521, 1998, 8)
GO

-- %% [markdown]
-- # [dbo].[Authors]

-- %%
INSERT [dbo].[Authors] ([AuthorId], [FirstName], [LastName], [Email]) VALUES (201, N'Saeed', N'Saleem', N'saeed@gmail.con')
GO

-- %% [markdown]
-- # [dbo].[Books]

-- %%
INSERT [dbo].[Books] ([ISBN], [Title], [QOH], [Price], [CategoryId], [PublisherId]) VALUES (204060, N'C#', 3, 200, 4, 321)
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
INSERT [dbo].[Categories] ([CategoryId], [CategoryName]) VALUES (4, N'Computer Languages')
GO

-- %% [markdown]
-- # [dbo].[Customers]

-- %%
INSERT [dbo].[Customers] ([CustomerId], [CustomerName], [PhoneNumber], [Email], [FaxNumber], [StreetName], [City], [PosalCode], [CreditLimt]) VALUES (20145, N'Vanier', 514745665, N'vanier@hotmail.com', 2014547896, N'Laurin', N'Montreal', N'H4N 2L1', 201)
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
INSERT [dbo].[Employees] ([EmployeeId], [FirstName], [LastName], [Phone], [Email], [JobId]) VALUES (1111, N'Henry', N'Brown', 514674884, N'brown45@gmail.com', 20)
INSERT [dbo].[Employees] ([EmployeeId], [FirstName], [LastName], [Phone], [Email], [JobId]) VALUES (2222, N'Thomas', N'Moore', 514215562, N'thomas@hotmail.com', 21)
INSERT [dbo].[Employees] ([EmployeeId], [FirstName], [LastName], [Phone], [Email], [JobId]) VALUES (3333, N'Peter', N'Wang', 514214203, N'wang@gmail.com', 22)
INSERT [dbo].[Employees] ([EmployeeId], [FirstName], [LastName], [Phone], [Email], [JobId]) VALUES (4444, N'Mary ', N'Brown', 514214778, N'brown20@gmail.com', 23)
INSERT [dbo].[Employees] ([EmployeeId], [FirstName], [LastName], [Phone], [Email], [JobId]) VALUES (5555, N'Jennifer', N'Bouchard', 514254521, N'Jennifer@gmail.com', 24)
GO

-- %% [markdown]
-- # [dbo].[Job]

-- %%
INSERT [dbo].[Job] ([JobId], [JobTitle]) VALUES (20, N'MISManager')
INSERT [dbo].[Job] ([JobId], [JobTitle]) VALUES (21, N'SalesManager')
INSERT [dbo].[Job] ([JobId], [JobTitle]) VALUES (22, N'InventoryController')
INSERT [dbo].[Job] ([JobId], [JobTitle]) VALUES (23, N'Order Clerks')
GO

-- %% [markdown]
-- # [dbo].[Publishers]

-- %%
INSERT [dbo].[Publishers] ([PublisherId], [PublisherName], [WebSite]) VALUES (321, N'Max', N'max.com   ')
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
INSERT [dbo].[Users] ([UserId], [Password], [UserStatus], [EmployeeId]) VALUES (1111, N'henryb', N'Active', 1111)
INSERT [dbo].[Users] ([UserId], [Password], [UserStatus], [EmployeeId]) VALUES (2222, N'thomas', N'Active', 2222)
INSERT [dbo].[Users] ([UserId], [Password], [UserStatus], [EmployeeId]) VALUES (3333, N'peterw', N'Active', 3333)
INSERT [dbo].[Users] ([UserId], [Password], [UserStatus], [EmployeeId]) VALUES (4444, N'maryb', N'Active', 4444)
INSERT [dbo].[Users] ([UserId], [Password], [UserStatus], [EmployeeId]) VALUES (5555, N'JenniferB', N'Active', 5555)
GO

-- %% [markdown]
-- # [HitTechDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [HitTechDB] SET  READ_WRITE 
GO
